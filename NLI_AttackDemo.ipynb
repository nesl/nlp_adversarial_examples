# %%
import keras
import numpy as np
import pickle
from time import time

# %%
from snli_rnn import build_model
from attacks import EntailmentAttack
# Out:
# 82
# 62
# 59
# 55
# 57
# 30
# RNN / Embed / Sent = None, 300, 300
# GloVe / Trainable Word Embeddings = True, False

# %%
# %load_ext autoreload
# %autoreload 2

# %%
with open('./nli_tokenizer.pkl', 'rb') as fh:
    tokenizer = pickle.load(fh)

# %%
with open('./nli_testing.pkl', 'rb') as fh:
    test = pickle.load(fh)

vocab= {w:i for (w, i) in tokenizer.word_index.items()}
inv_vocab = {i:w for (w,i) in vocab.items()}

# %%
def reconstruct(sent, inv_vocab):
    word_list = [inv_vocab[w] for w in sent if w != 0]
    return ' '.join(word_list)

# %% [markdown]
# ## Building the model

# %%
VOCAB = len(tokenizer.word_counts) + 1
LABELS = {'contradiction': 0, 'neutral': 1, 'entailment': 2}

# %%
model = build_model()
# Out:
# Loading GloVe
# Total number of null word embeddings:
# 4043
# /home/malzantot/Nesl/nlp_adversarial_examples/snli_rnn.py:179: UserWarning: Update your `Dense` call to the Keras 2 API: `Dense(600, activation="relu", kernel_regularizer=<keras.reg...)`
#   W_regularizer=l2(L2) if L2 else None)(joint)
# /home/malzantot/Nesl/nlp_adversarial_examples/snli_rnn.py:184: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=[<tf.Tenso..., outputs=Tensor("de...)`
#   model = Model(input=[premise, hypothesis], output=pred)

# %%
model.load_weights('./nli_model.h5')

# %% [markdown]
# ## Test accuracy

# %%
test_accuracy = model.evaluate([test[0], test[1]], test[2])[1]
print('\nTest accuracy = ', test_accuracy)
# Out:
# 9824/9824 [==============================] - 1s 128us/step
#
# Test accuracy =  0.8136197068403909

# %% [markdown]
# ## Fooling the model

# %%
dist_mat = np.load('./aux_files/nli_dist_counter_42390.npy')
skip_words = np.load('./aux_files/nli_missed_embeddings_counter_42390.npy')

# %%
def visulaize_result(model, attack_input, attack_output):
    str_labels = ['Contradiction', 'neutral', 'entailment']
    orig_pred = model.predict(attack_input)
    adv_pred = model.predict([attack_output[0][np.newaxis,:], attack_output[1][np.newaxis,:]])
    print('Original pred = {} ({:.2f})'.format(str_labels[np.argmax(orig_pred[0])], np.max(orig_pred[0])))
    print(reconstruct(attack_input[0].ravel(), inv_vocab) , ' || ', reconstruct(attack_input[1].ravel(), inv_vocab))
    print('-' * 40)
    print('New pred = {} ({:.2f})'.format(str_labels[np.argmax(adv_pred[0])], np.max(adv_pred[0])))
    print(reconstruct(attack_output[0].ravel(), inv_vocab) , ' || ', reconstruct(attack_output[1].ravel(), inv_vocab))

# %%
adversary = EntailmentAttack(model, dist_mat, pop_size=128, max_iters=12, n1=5)

# %%
TEST_SIZE = 500
test_idxs = np.random.choice(len(test[0]), size=TEST_SIZE, replace=False)
test_list = []
input_list = []
output_list = []
dist_list = []

# %%
test_times = []

# %%
success_count = 0
for i in range(TEST_SIZE):
    print('\n')
    test_idx = test_idxs[i]
    attack_input = [test[0][test_idx][np.newaxis,:], test[1][test_idx][np.newaxis,:]]
    if np.sum(np.sign(attack_input[1])) < 10:
        continue
    attack_pred = np.argmax(model.predict(attack_input))
    true_label = np.argmax(test[2][test_idx])
    if attack_pred != true_label:
        print('Wrong classified')
    else:
        if true_label == 2:
            target = 0
        elif true_label == 0:
            target = 2
        else:
            target = 0 if np.random.uniform() < 0.5 else 2
        start_time = time()
        attack_result = adversary.attack(attack_input, target)
        if attack_result is None:
            print('**** Attack failed **** ')
        else:
            success_count += 1
            print('***** DONE ', len(test_list) , '------' )
            visulaize_result(model, attack_input, attack_result)
            test_times.append(time()-start_time)
        test_list.append(test_idx)
        input_list.append(attack_input)
        output_list.append(attack_result)
print(success_count / len(test_list))
# Out:
# 0  :  0.037441637
# 1  :  0.074287295
# 2  :  0.23543617
# 3  :  0.23543617
# 4  :  0.23543617
# 5  :  0.23543617
# 6  :  0.32830888
# 7  :  0.32830888
# 8  :  0.32830888
# 9  :  0.32830888
# 10  :  0.32830888
# 11  :  0.32830888
# **** Attack failed ****
#
#
# 0  :  0.41141328
# ***** DONE  1 ------
# Original pred = neutral (0.72)
# A man speaking with two women .  ||  A man is giving two women directions at work .
# ----------------------------------------
# New pred = Contradiction (0.64)
# A man speaking with two women .  ||  A man is giving two women directions into working .
#
#
#
#
#
#
#
#
#
#
#
#
# Wrong classified
#
#
#
#
#
#
# ***** DONE  2 ------
# Original pred = neutral (0.50)
# The black woman is laying out literature .  ||  A woman is placing pamphlets on a display table .
# ----------------------------------------
# New pred = Contradiction (0.63)
# The black woman is laying out literature .  ||  A woman is placing pamphlets on a display chalkboard .
#
#
#
#
# 0  :  0.18540055
# 1  :  0.29953915
# ***** DONE  3 ------
# Original pred = neutral (0.97)
# A surfer showing off his talent in public using a man-made water machine .  ||  A surfer is in performing at a charity event .
# ----------------------------------------
# New pred = entailment (0.75)
# A surfer showing off his talent in public using a man-made water machine .  ||  A surfs exists in performing at a charitable happenings .
#
#
#
#
# 0  :  0.030661428
# 1  :  0.04682773
# 2  :  0.054565422
# 3  :  0.09021993
# 4  :  0.1264544
# 5  :  0.13246606
# 6  :  0.1985045
# 7  :  0.1985045
# 8  :  0.1985045
# 9  :  0.2035849
# 10  :  0.34446034
# 11  :  0.34446034
# **** Attack failed ****
#
#
# Wrong classified
#
#
#
#
# 0  :  0.23937438
# 1  :  0.41714883
# ***** DONE  5 ------
# Original pred = neutral (0.93)
# A man wearing a white button down shirt is walking down the street .  ||  The man is on his way to a movie .
# ----------------------------------------
# New pred = Contradiction (0.63)
# A man wearing a white button down shirt is walking down the street .  ||  The man is on his path the a movies .
#
#
#
#
#
#
# 0  :  0.015492537
# 1  :  0.057752978
# 2  :  0.12560262
# 3  :  0.14651857
# 4  :  0.17399596
# 5  :  0.17399596
# 6  :  0.22073711
# 7  :  0.22073711
# ***** DONE  6 ------
# Original pred = Contradiction (0.95)
# A skateboarder is performing a grab trick while hovering above a ramp , which is located within a city .  ||  A skateboarder is in his backyard wrestling with his friends .
# ----------------------------------------
# New pred = entailment (0.42)
# A skateboarder is performing a grab trick while hovering above a ramp , which is located within a city .  ||  A skateboarder exists during his courtyard tussle with him mates .
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
# 0  :  0.2702196
# 1  :  0.3475566
# 2  :  0.3475566
# 3  :  0.40200096
# 4  :  0.42027652
# ***** DONE  7 ------
# Original pred = neutral (0.68)
# Three women are dancing among the bamboo .  ||  A group of women on the dance floor decorated with bamboo .
# ----------------------------------------
# New pred = Contradiction (0.50)
# Three women are dancing among the bamboo .  ||  A panel of woman on the dancer floor adorned with bamboo .
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.370631
# ***** DONE  8 ------
# Original pred = neutral (0.75)
# A child doing gymnastics  ||  A child is doing gymnastics in front of a crowd .
# ----------------------------------------
# New pred = Contradiction (0.81)
# A child doing gymnastics  ||  A child is doing weightlifting in front of a multitude .
#
#
#
#
#
#
#
#
# ***** DONE  9 ------
# Original pred = neutral (0.89)
# A man riding a motorcycle on a dirt road passing several junk or abandoned cars on the side of the road .  ||  A man is making a cross country trip on his motorcycle .
# ----------------------------------------
# New pred = Contradiction (0.55)
# A man riding a motorcycle on a dirt road passing several junk or abandoned cars on the side of the road .  ||  A man is making a cross country trip on his bicycles .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***** DONE  10 ------
# Original pred = Contradiction (1.00)
# a soccer player with black and red striped uniform gets ready to kick the soccer ball  ||  a football player gets ready to throw the ball .
# ----------------------------------------
# New pred = entailment (0.58)
# a soccer player with black and red striped uniform gets ready to kick the soccer ball  ||  a soccer player gets ready to throw the ball .
#
#
#
#
# 0  :  0.15575886
# 1  :  0.244888
# 2  :  0.36653233
# 3  :  0.36653233
# 4  :  0.36653233
# 5  :  0.3959489
# 6  :  0.3959489
# 7  :  0.3959489
# 8  :  0.40001106
# 9  :  0.40001106
# 10  :  0.40001106
# 11  :  0.40001106
# **** Attack failed ****
#
#
#
#
#
#
#
#
# 0  :  0.08450952
# 1  :  0.09605365
# 2  :  0.09605365
# 3  :  0.09605365
# 4  :  0.09621987
# 5  :  0.09621987
# 6  :  0.09635231
# 7  :  0.09635231
# 8  :  0.09805756
# 9  :  0.11632942
# 10  :  0.11632942
# 11  :  0.11632942
# **** Attack failed ****
#
#
#
#
#
#
# Wrong classified
#
#
#
#
#
#
# 0  :  0.27182192
# ***** DONE  13 ------
# Original pred = Contradiction (0.97)
# A man is sitting at a restaurant table outdoors .  ||  The man is inside the restaurant in a booth .
# ----------------------------------------
# New pred = entailment (0.67)
# A man is sitting at a restaurant table outdoors .  ||  The man is inner the dine during a booth .
#
#
#
#
#
#
# 0  :  0.0068228752
# 1  :  0.08932678
# 2  :  0.16866238
# ***** DONE  14 ------
# Original pred = Contradiction (0.94)
# The little boy stands in the middle of birds who have gathered on the sidewalk .  ||  The boy is in the dog park with a bunch of dogs .
# ----------------------------------------
# New pred = entailment (0.53)
# The little boy stands in the middle of birds who have gathered on the sidewalk .  ||  The fella exists in the pooch park with a bunch of doggies .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wrong classified
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
# ***** DONE  15 ------
# Original pred = Contradiction (0.69)
# A man is riding up an escalator that is carrying shopping carts .  ||  The man is sitting on table not doing anything .
# ----------------------------------------
# New pred = entailment (0.86)
# A man is riding up an escalator that is carrying shopping carts .  ||  The man is sitting on table not doing none .
#
#
#
#
#
#
# 0  :  0.012137348
# 1  :  0.023304543
# 2  :  0.02892213
# 3  :  0.03817609
# 4  :  0.03817609
# 5  :  0.03817609
# 6  :  0.11207672
# 7  :  0.17905602
# 8  :  0.17905602
# 9  :  0.2595548
# 10  :  0.2632258
# 11  :  0.2632258
# **** Attack failed ****
#
#
#
#
# 0  :  0.14321241
# 1  :  0.40049434
# 2  :  0.40049434
# 3  :  0.40049434
# 4  :  0.40049434
# ***** DONE  17 ------
# Original pred = neutral (0.90)
# A man wearing headphones and a breathing mask works on a white sculpture .  ||  a man wearing headphones working on a sculpture of his friend
# ----------------------------------------
# New pred = entailment (0.52)
# A man wearing headphones and a breathing mask works on a white sculpture .  ||  a fella wearing headset work on a sculpture of his amigo
#
#
#
#
#
#
#
#
# ***** DONE  18 ------
# Original pred = entailment (0.67)
# A group of people watch a breakdancer in a red jacket do a one-handed trick .  ||  are made by a person in a red jacket while people watching him .
# ----------------------------------------
# New pred = Contradiction (0.82)
# A group of people watch a breakdancer in a red jacket do a one-handed trick .  ||  are made by a anybody in a red jacket while people watching him .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.26185152
# 1  :  0.28278682
# 2  :  0.28278682
# 3  :  0.2910506
# ***** DONE  19 ------
# Original pred = neutral (0.88)
# A person just about to stand up while water-skiing , while people in the background watch and take photos .  ||  The person water-skiing is about to hit a big wave .
# ----------------------------------------
# New pred = entailment (0.46)
# A person just about to stand up while water-skiing , while people in the background watch and take photos .  ||  The person water-skiing exists about to hit a vast waving .
#
#
#
#
#
#
#
#
#
#
# ***** DONE  20 ------
# Original pred = neutral (0.47)
# A young girl with a purple shirt and a pink hair band standing near the woods .  ||  A little girl in a pink shirt is ready to run in the woods .
# ----------------------------------------
# New pred = Contradiction (0.67)
# A young girl with a purple shirt and a pink hair band standing near the woods .  ||  A little girl in a pink polo is ready to run in the woods .
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.034853313
# 1  :  0.10669217
# 2  :  0.1781131
# 3  :  0.18250787
# 4  :  0.18250787
# 5  :  0.34263983
# 6  :  0.34263983
# 7  :  0.34263983
# 8  :  0.34263983
# 9  :  0.34263983
# 10  :  0.34263983
# ***** DONE  21 ------
# Original pred = Contradiction (0.99)
# A little girl with pointy pigtails is sitting in the sand on the beach .  ||  The girl runs through the grass outside her school .
# ----------------------------------------
# New pred = entailment (0.57)
# A little girl with pointy pigtails is sitting in the sand on the beach .  ||  The woman operates through the grass outside her educational .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***** DONE  22 ------
# Original pred = neutral (0.49)
# A group of women and men are in the water wit their clothes on .  ||  The group of people are swimming in the water .
# ----------------------------------------
# New pred = Contradiction (0.53)
# A group of women and men are in the water wit their clothes on .  ||  The group of people are swam in the water .
#
#
#
#
# 0  :  0.31411994
# ***** DONE  23 ------
# Original pred = Contradiction (0.52)
# A man and a woman walk at a flea market .  ||  The man and women are at a high priced store .
# ----------------------------------------
# New pred = entailment (0.60)
# A man and a woman walk at a flea market .  ||  The males and female are under a high priced store .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***** DONE  24 ------
# Original pred = neutral (0.84)
# A man stands on a dock near several boats , while 2 other men are on one of the boats .  ||  A man with brown hair is standing on a dock .
# ----------------------------------------
# New pred = entailment (0.49)
# A man stands on a dock near several boats , while 2 other men are on one of the boats .  ||  A man with brownish hair is standing on a dock .
#
#
#
#
#
#
#
#
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
# ***** DONE  25 ------
# Original pred = neutral (0.88)
# Two dogs run together near the leaves .  ||  The two dogs are running to play in the leaves .
# ----------------------------------------
# New pred = Contradiction (0.63)
# Two dogs run together near the leaves .  ||  The two dogs are running to play in the spreadsheets .
#
#
#
#
#
#
#
#
#
#
# 0  :  0.06665576
# 1  :  0.0998121
# 2  :  0.0998121
# 3  :  0.14375259
# 4  :  0.15011972
# 5  :  0.15011972
# 6  :  0.15011972
# 7  :  0.15011972
# 8  :  0.17383714
# 9  :  0.17383714
# 10  :  0.17383714
# 11  :  0.17383714
# **** Attack failed ****
#
#
#
#
#
#
# 0  :  0.03021502
# 1  :  0.095350765
# ***** DONE  27 ------
# Original pred = Contradiction (0.98)
# A woman in a red long-sleeved shirt and blue jeans stands at the lectern speaking at or about U .  ||  A woman is doing a stage dive into a crowd .
# ----------------------------------------
# New pred = entailment (0.69)
# A woman in a red long-sleeved shirt and blue jeans stands at the lectern speaking at or about U .  ||  A female is accomplished a stage divers into a myriad .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.25444037
# ***** DONE  28 ------
# Original pred = Contradiction (0.75)
# a young woman siting on a park bench in the sun .  ||  The young woman is sitting on a bench in the rain .
# ----------------------------------------
# New pred = entailment (0.45)
# a young woman siting on a park bench in the sun .  ||  The youthful woman exists sitting on a bench in the rain .
#
#
#
#
#
#
# Wrong classified
#
#
# 0  :  0.16270506
# ***** DONE  29 ------
# Original pred = entailment (0.88)
# A man standing in front of a building on the phone as two men to the side pain on the side .  ||  a guy near a building stands by two other men
# ----------------------------------------
# New pred = Contradiction (0.44)
# A man standing in front of a building on the phone as two men to the side pain on the side .  ||  a boy close a build stands by two other men
#
#
#
#
#
#
#
#
# 0  :  0.013027946
# 1  :  0.014871368
# 2  :  0.015148593
# 3  :  0.015148593
# 4  :  0.015148593
# 5  :  0.015148593
# 6  :  0.015148593
# 7  :  0.015148593
# 8  :  0.015148593
# 9  :  0.015148593
# 10  :  0.015148593
# 11  :  0.015148593
# **** Attack failed ****
#
#
# Wrong classified
#
#
# ***** DONE  31 ------
# Original pred = entailment (0.82)
# The firefighter has a hose ready to tackle a car fire .  ||  A firefighter is about to put out a fire .
# ----------------------------------------
# New pred = Contradiction (0.45)
# The firefighter has a hose ready to tackle a car fire .  ||  A firefighter is about to put out a bonfire .
#
#
#
#
# Wrong classified
#
#
#
#
# ***** DONE  32 ------
# Original pred = Contradiction (0.62)
# A bike is parked against a window to a store called Winter Sport where inside some people sit next to a computer and an older woman stands in the background .  ||  A woman rides her bike away from a store .
# ----------------------------------------
# New pred = entailment (0.74)
# A bike is parked against a window to a store called Winter Sport where inside some people sit next to a computer and an older woman stands in the background .  ||  A woman rides her bike outside from a store .
#
#
# Wrong classified
#
#
#
#
# 0  :  0.3695708
# 1  :  0.40130952
# ***** DONE  33 ------
# Original pred = neutral (0.78)
# A group of people are in a rowboat in the ocean surrounded by seagulls .  ||  A group of people are rowing towards some islands while one of them fishes .
# ----------------------------------------
# New pred = entailment (0.51)
# A group of people are in a rowboat in the ocean surrounded by seagulls .  ||  A clusters of humans are rowing towards some islands while one of them reptile .
#
#
# 0  :  0.29884478
# 1  :  0.31979805
# ***** DONE  34 ------
# Original pred = Contradiction (0.49)
# A man in a colorful shirt and a lady in a white blouse sign copies of books for people .  ||  A man in a colorful shirt and a lady in a white blouse give candy to people .
# ----------------------------------------
# New pred = entailment (0.49)
# A man in a colorful shirt and a lady in a white blouse sign copies of books for people .  ||  A fella in a colorful shirt and a lady in a white frock provide confectionery to people .
#
#
#
#
#
#
#
#
# 0  :  0.00020983983
# 1  :  0.00036737687
# 2  :  0.00072817603
# 3  :  0.00075222144
# 4  :  0.0013749971
# 5  :  0.0029112252
# 6  :  0.0029112252
# 7  :  0.0041235615
# 8  :  0.0074081733
# 9  :  0.0074081733
# 10  :  0.0074081733
# 11  :  0.0074081733
# **** Attack failed ****
#
#
#
#
# ***** DONE  36 ------
# Original pred = neutral (0.46)
# A young girl in a helmet walks barefoot across a mossy tree trunk that is lying over water .  ||  A girl does n't like balancing on a tree .
# ----------------------------------------
# New pred = Contradiction (0.49)
# A young girl in a helmet walks barefoot across a mossy tree trunk that is lying over water .  ||  A girl does n't like balancing on a arbor .
#
#
# 0  :  0.13579227
# ***** DONE  37 ------
# Original pred = entailment (0.92)
# A woman in a black jacket and a black and white striped skirt is watching a woman talking to a little boy sitting on concrete steps .  ||  A person is talking to a child while another person watches .
# ----------------------------------------
# New pred = Contradiction (0.59)
# A woman in a black jacket and a black and white striped skirt is watching a woman talking to a little boy sitting on concrete steps .  ||  A anybody is conversations to a child while another anybody watches .
#
#
#
#
#
#
#
#
#
#
# 0  :  0.032229945
# 1  :  0.032229945
# 2  :  0.059304364
# 3  :  0.059304364
# 4  :  0.095738456
# 5  :  0.14691651
# 6  :  0.14691651
# 7  :  0.14691651
# 8  :  0.14691651
# 9  :  0.14691651
# 10  :  0.14691651
# 11  :  0.14691651
# **** Attack failed ****
#
#
# Wrong classified
#
#
#
#
#
#
#
#
#
#
# 0  :  0.34527302
# ***** DONE  39 ------
# Original pred = Contradiction (0.79)
# Under the glaring light of a fluorescent bulb , men in dark clothing and hats approach fare card machines ; one older man in a blue scarf glances up as he puts on his gloves .  ||  The men are wearing bright suits in the park .
# ----------------------------------------
# New pred = entailment (0.68)
# Under the glaring light of a fluorescent bulb , men in dark clothing and hats approach fare card machines ; one older man in a blue scarf glances up as he puts on his gloves .  ||  The men are wearing bright suits in du playpen .
#
#
# 0  :  0.035093535
# 1  :  0.03523541
# 2  :  0.08791201
# 3  :  0.10138323
# 4  :  0.10138323
# 5  :  0.10138323
# 6  :  0.16901393
# 7  :  0.16901393
# 8  :  0.30943057
# 9  :  0.30943057
# 10  :  0.30943057
# 11  :  0.30943057
# **** Attack failed ****
#
#
# ***** DONE  41 ------
# Original pred = entailment (0.42)
# Casually dressed young males and females are sitting and laying on a grassy area with bicycles and other personal belongings reading on a sunny day .  ||  people are hanging outside with their bicycles on the grass .
# ----------------------------------------
# New pred = Contradiction (0.90)
# Casually dressed young males and females are sitting and laying on a grassy area with bicycles and other personal belongings reading on a sunny day .  ||  people are hanging outer with their bicycles on the grass .
#
#
# Wrong classified
#
#
#
#
#
#
# Wrong classified
#
#
#
#
#
#
# 0  :  0.0056228805
# 1  :  0.010248993
# 2  :  0.01748251
# 3  :  0.01748251
# 4  :  0.030581737
# 5  :  0.033141002
# 6  :  0.0592722
# 7  :  0.0798739
# 8  :  0.0798739
# 9  :  0.0798739
# 10  :  0.0798739
# 11  :  0.0798739
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.01514198
# 1  :  0.059656058
# 2  :  0.07494654
# 3  :  0.14267392
# 4  :  0.14267392
# 5  :  0.14267392
# 6  :  0.14267392
# 7  :  0.14267392
# 8  :  0.14267392
# 9  :  0.14267392
# 10  :  0.14267392
# 11  :  0.14267392
# **** Attack failed ****
#
#
#
#
#
#
#
#
# 0  :  0.05510516
# 1  :  0.116687335
# 2  :  0.16135907
# 3  :  0.21018296
# 4  :  0.21018296
# 5  :  0.21018296
# 6  :  0.23277274
# 7  :  0.23277274
# 8  :  0.26863194
# 9  :  0.26863194
# 10  :  0.26863194
# 11  :  0.26863194
# **** Attack failed ****
#
#
#
#
# 0  :  0.06383987
# 1  :  0.12741238
# 2  :  0.16217782
# 3  :  0.16217782
# 4  :  0.22260858
# 5  :  0.22260858
# 6  :  0.41564083
# 7  :  0.41564083
# 8  :  0.41564083
# 9  :  0.41564083
# 10  :  0.41564083
# 11  :  0.41564083
# **** Attack failed ****
#
#
#
#
# 0  :  0.023409246
# 1  :  0.034021143
# 2  :  0.045576684
# 3  :  0.045576684
# 4  :  0.045576684
# 5  :  0.045576684
# 6  :  0.045576684
# 7  :  0.06463196
# 8  :  0.06463196
# 9  :  0.06463196
# 10  :  0.06463196
# 11  :  0.06463196
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
#
#
# 0  :  0.040980402
# 1  :  0.08482675
# 2  :  0.13490365
# 3  :  0.15334733
# 4  :  0.18600288
# 5  :  0.18600288
# 6  :  0.18600288
# 7  :  0.27315414
# 8  :  0.27315414
# 9  :  0.27315414
# 10  :  0.27315414
# 11  :  0.27315414
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
# 0  :  0.37617308
# ***** DONE  48 ------
# Original pred = neutral (0.61)
# An older gentleman wearing a hat is walking on crutches next to a busy street .  ||  A man on crutches is trying to cross the street .
# ----------------------------------------
# New pred = Contradiction (0.63)
# An older gentleman wearing a hat is walking on crutches next to a busy street .  ||  A males on crutches is attempting the cross the street .
#
#
#
#
#
#
#
#
# ***** DONE  49 ------
# Original pred = neutral (0.75)
# Two men with graying beards share a laugh while enjoying the nice weather .  ||  The men are laughing about the us losing the cold war .
# ----------------------------------------
# New pred = Contradiction (0.57)
# Two men with graying beards share a laugh while enjoying the nice weather .  ||  The men are laughing about the us wasting the cold war .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.15547071
# 1  :  0.16745986
# 2  :  0.23491684
# 3  :  0.28357992
# 4  :  0.28357992
# 5  :  0.28357992
# 6  :  0.28357992
# 7  :  0.28357992
# 8  :  0.28357992
# 9  :  0.28357992
# 10  :  0.28357992
# 11  :  0.28357992
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.0014848586
# 1  :  0.0074612983
# 2  :  0.015987787
# 3  :  0.033450216
# 4  :  0.033450216
# 5  :  0.06872424
# 6  :  0.06872424
# 7  :  0.06872424
# 8  :  0.06872424
# 9  :  0.07967022
# 10  :  0.07967022
# 11  :  0.07967022
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
# ***** DONE  52 ------
# Original pred = neutral (0.68)
# A man with no shirt on is holding a football .  ||  A man poses for a photo with a football .
# ----------------------------------------
# New pred = entailment (0.81)
# A man with no shirt on is holding a football .  ||  A man poses in a photo with a football .
#
#
# 0  :  0.20200296
# ***** DONE  53 ------
# Original pred = Contradiction (0.73)
# A group of people look at fresh lettuce in at the local street market .  ||  A group of dogs look at fresh lettuce in at the local street market .
# ----------------------------------------
# New pred = entailment (0.49)
# A group of people look at fresh lettuce in at the local street market .  ||  A group of doggies look at fresh cucumbers in at the locale street market .
#
#
#
#
#
#
#
#
# 0  :  0.23995015
# 1  :  0.4158289
# ***** DONE  54 ------
# Original pred = neutral (0.78)
# An old man with a package poses in front of an advertisement .  ||  A man poses in front of an ad for beer .
# ----------------------------------------
# New pred = entailment (0.60)
# An old man with a package poses in front of an advertisement .  ||  A fella brings in front of an ad in casket .
#
#
#
#
#
#
# 0  :  0.17686424
# 1  :  0.23384276
# 2  :  0.40719727
# ***** DONE  55 ------
# Original pred = Contradiction (0.72)
# Six males , four with shirts and two without , have taken a break from their construction work on a building .  ||  A soccer team is standing outside of a building .
# ----------------------------------------
# New pred = entailment (0.44)
# Six males , four with shirts and two without , have taken a break from their construction work on a building .  ||  A soccer team exists permanent outside of a construction .
#
#
# 0  :  0.06693942
# 1  :  0.18042377
# 2  :  0.42698064
# 3  :  0.42698064
# 4  :  0.42698064
# 5  :  0.42698064
# 6  :  0.42698064
# 7  :  0.42698064
# 8  :  0.42698064
# ***** DONE  56 ------
# Original pred = neutral (0.93)
# Asian men sitting down , and some of them are wearing white and pink hats , while the others are wearing blue jackets with yellow sashes .  ||  A group of adults are waiting for an event .
# ----------------------------------------
# New pred = entailment (0.61)
# Asian men sitting down , and some of them are wearing white and pink hats , while the others are wearing blue jackets with yellow sashes .  ||  A group of grownup are await onto an happenings .
#
#
# 0  :  0.14713243
# 1  :  0.14713243
# 2  :  0.22945507
# 3  :  0.22945507
# 4  :  0.22945507
# 5  :  0.22945507
# 6  :  0.22945507
# 7  :  0.30434114
# 8  :  0.30434114
# 9  :  0.30434114
# 10  :  0.30434114
# 11  :  0.30434114
# **** Attack failed ****
#
#
# 0  :  0.24286452
# 1  :  0.3669374
# ***** DONE  58 ------
# Original pred = neutral (0.85)
# Many people on the beach holding a very large net .  ||  The people are a part of a native tribe mending their fishing nets .
# ----------------------------------------
# New pred = Contradiction (0.54)
# Many people on the beach holding a very large net .  ||  The citizens are a portions of a native clan mending their fishing filet .
#
#
#
#
#
#
# 0  :  0.45069253
# ***** DONE  59 ------
# Original pred = neutral (0.91)
# An ATV rides over a vast sandy landscape .  ||  The rider is following his friends in the sand .
# ----------------------------------------
# New pred = Contradiction (0.61)
# An ATV rides over a vast sandy landscape .  ||  The knight is later his friends in the sand .
#
#
# 0  :  0.12894718
# 1  :  0.36954477
# ***** DONE  60 ------
# Original pred = neutral (0.92)
# A young woman is standing on a slope , facing the top of the slope .  ||  A woman ponders what it would be like to climb the slope .
# ----------------------------------------
# New pred = Contradiction (0.55)
# A young woman is standing on a slope , facing the top of the slope .  ||  A dame ponders what it could be like to rises du slope .
#
#
# 0  :  0.34277898
# 1  :  0.3658085
# 2  :  0.42654097
# 3  :  0.46242675
# 4  :  0.46242675
# ***** DONE  61 ------
# Original pred = neutral (0.88)
# This man dressed in white pants and blue shirt , is standing on a ledge in the snow .  ||  A man is getting ready to shovel the snow so he can park his car .
# ----------------------------------------
# New pred = Contradiction (0.50)
# This man dressed in white pants and blue shirt , is standing on a ledge in the snow .  ||  A man is getting ready of shovel de snow therefore he can playpen his car .
#
#
#
#
# 0  :  0.27866575
# ***** DONE  62 ------
# Original pred = neutral (0.88)
# Several people browse through books at a store with a tile floor .  ||  There are a lot of people looking for a certain book at the local Barnes and Noble .
# ----------------------------------------
# New pred = Contradiction (0.51)
# Several people browse through books at a store with a tile floor .  ||  There are a lot of people quest for a certain ledger at the local Barnes and Noble .
#
#
#
#
# 0  :  0.0018665222
# 1  :  0.018822856
# 2  :  0.029369123
# 3  :  0.03162224
# 4  :  0.039674535
# 5  :  0.05467094
# 6  :  0.05467094
# 7  :  0.07970138
# 8  :  0.07970138
# 9  :  0.07970138
# 10  :  0.07970138
# 11  :  0.07970138
# **** Attack failed ****
#
#
#
#
#
#
#
#
# 0  :  0.19539766
# 1  :  0.30752504
# ***** DONE  64 ------
# Original pred = neutral (0.65)
# A woman examines a poster mounted on the wall of a tunnel or hallway lit by overhead fluorescent lights .  ||  A woman is lost and looks at directions mounted on the wall .
# ----------------------------------------
# New pred = entailment (0.41)
# A woman examines a poster mounted on the wall of a tunnel or hallway lit by overhead fluorescent lights .  ||  A women is disappeared and looks at direction mounted on the wall .
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.2126083
# 1  :  0.31206068
# 2  :  0.4480375
# ***** DONE  65 ------
# Original pred = neutral (0.79)
# A woman is leaning against a wall with her shoe off .  ||  A woman has her shoe off to adjust her sock .
# ----------------------------------------
# New pred = entailment (0.56)
# A woman is leaning against a wall with her shoe off .  ||  A woman possesses her footwear off of adaptation her sock .
#
#
# 0  :  0.1465907
# 1  :  0.2047897
# 2  :  0.39871255
# 3  :  0.39871255
# 4  :  0.39871255
# ***** DONE  66 ------
# Original pred = neutral (0.93)
# A group of people sitting around tables with computer monitors on them paying attention to something on the left .  ||  The group of people are game developers creating a new video game in their office .
# ----------------------------------------
# New pred = Contradiction (0.50)
# A group of people sitting around tables with computer monitors on them paying attention to something on the left .  ||  The panels de citizens be ballgame builders creating a new videos ballgame in their office .
#
#
#
#
#
#
#
#
# 0  :  0.041457094
# 1  :  0.08298215
# 2  :  0.11446266
# 3  :  0.11561117
# 4  :  0.15208513
# 5  :  0.17875914
# 6  :  0.23133644
# 7  :  0.31308672
# 8  :  0.31308672
# 9  :  0.40557674
# 10  :  0.40557674
# 11  :  0.42060444
# **** Attack failed ****
#
#
#
#
# 0  :  0.35411432
# ***** DONE  68 ------
# Original pred = neutral (0.84)
# A yellow backhoe near a large pile of dirt and rocks near a blue machine with a worker standing on it .  ||  A worker is working on the damages caused by the flood .
# ----------------------------------------
# New pred = Contradiction (0.50)
# A yellow backhoe near a large pile of dirt and rocks near a blue machine with a worker standing on it .  ||  A worker is working on the harming caused by de flood .
#
#
#
#
#
#
#
#
#
#
# 0  :  0.2864158
# 1  :  0.4122138
# ***** DONE  69 ------
# Original pred = neutral (0.89)
# Two women are hugging on a path through a grassy area with a cow visible past them .  ||  the women have rounded up the last cow for the fall
# ----------------------------------------
# New pred = Contradiction (0.53)
# Two women are hugging on a path through a grassy area with a cow visible past them .  ||  du females have rounded up the latter cow per the slumps
#
#
#
#
#
#
# 0  :  0.037480377
# 1  :  0.07414031
# 2  :  0.14390783
# 3  :  0.15724117
# 4  :  0.23639463
# 5  :  0.31889844
# 6  :  0.31889844
# 7  :  0.31889844
# 8  :  0.31889844
# 9  :  0.31889844
# ***** DONE  70 ------
# Original pred = neutral (0.97)
# A man in an apron smiles as he pokes a frying donut with a little metal stick .  ||  The man is in the kitchen of a restaurant .
# ----------------------------------------
# New pred = Contradiction (0.35)
# A man in an apron smiles as he pokes a frying donut with a little metal stick .  ||  The men is throughout du galley du a dine .
#
#
#
#
# 0  :  0.006777854
# 1  :  0.01898522
# 2  :  0.022877974
# 3  :  0.022877974
# 4  :  0.024876745
# 5  :  0.024876745
# 6  :  0.024876745
# 7  :  0.024876745
# 8  :  0.024876745
# 9  :  0.024876745
# 10  :  0.024876745
# 11  :  0.024876745
# **** Attack failed ****
#
#
#
#
#
#
#
#
# Wrong classified
#
#
# 0  :  0.4261668
# ***** DONE  72 ------
# Original pred = entailment (0.96)
# One child in black is walking down a hill covered in white snow while 2 children are on their knees .  ||  There are three children in this picture , and they are all outside .
# ----------------------------------------
# New pred = Contradiction (0.92)
# One child in black is walking down a hill covered in white snow while 2 children are on their knees .  ||  There are three children in this photograph , and they are everything outer .
#
#
#
#
# 0  :  0.072954774
# 1  :  0.115604654
# 2  :  0.1970011
# 3  :  0.1970011
# 4  :  0.1970011
# 5  :  0.20570321
# 6  :  0.20570321
# 7  :  0.20570321
# 8  :  0.20570321
# 9  :  0.20570321
# 10  :  0.20570321
# 11  :  0.20570321
# **** Attack failed ****
#
#
#
#
# 0  :  0.045551892
# 1  :  0.089087814
# 2  :  0.09500034
# 3  :  0.23761995
# 4  :  0.23761995
# 5  :  0.23761995
# 6  :  0.23761995
# 7  :  0.23761995
# 8  :  0.23761995
# 9  :  0.23761995
# 10  :  0.23761995
# 11  :  0.3701167
# **** Attack failed ****
#
#
#
#
# ***** DONE  75 ------
# Original pred = neutral (0.55)
# Some men in burgundy coats try to push a car in the snow .  ||  These men pushing the car off a cliff is from a scene in the movie Fargo .
# ----------------------------------------
# New pred = Contradiction (0.73)
# Some men in burgundy coats try to push a car in the snow .  ||  These men pushing the car disable a cliff is from a scene in the movie Fargo .
#
#
# 0  :  0.18227524
# 1  :  0.282327
# 2  :  0.32546517
# 3  :  0.32546517
# ***** DONE  76 ------
# Original pred = neutral (0.56)
# A woman is walking her dog and using her cellphone .  ||  The woman is playing a game on her cellphone .
# ----------------------------------------
# New pred = entailment (0.54)
# A woman is walking her dog and using her cellphone .  ||  The female exists playback a game on her portable .
#
#
#
#
#
#
# 0  :  0.168822
# 1  :  0.27780458
# 2  :  0.3061658
# 3  :  0.46693802
# ***** DONE  77 ------
# Original pred = entailment (0.93)
# A lady sitting on a bench with a book on her lap with a boy and girl on either side of her .  ||  A woman and two kids next to each other .
# ----------------------------------------
# New pred = Contradiction (0.59)
# A lady sitting on a bench with a book on her lap with a boy and girl on either side of her .  ||  A women and two infantile next pour everybody other .
#
#
#
#
#
#
#
#
#
#
# Wrong classified
#
#
# 0  :  0.37368652
# ***** DONE  78 ------
# Original pred = neutral (0.89)
# Two men working on the roof of an apartment building with a nice looking skyline behind them .  ||  Two men joyously working on the roof of an apartment building
# ----------------------------------------
# New pred = entailment (0.47)
# Two men working on the roof of an apartment building with a nice looking skyline behind them .  ||  Two males triumphantly working on the roof of an apartment building
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.10085956
# 1  :  0.1556366
# 2  :  0.1556366
# 3  :  0.20135817
# 4  :  0.20135817
# 5  :  0.20135817
# 6  :  0.20135817
# 7  :  0.22689845
# 8  :  0.22689845
# 9  :  0.22689845
# 10  :  0.27931735
# 11  :  0.27931735
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
# 0  :  0.39656237
# ***** DONE  80 ------
# Original pred = neutral (0.71)
# A man in a business suit screaming at the camera .  ||  A business man is giving a heated interview for the local news .
# ----------------------------------------
# New pred = Contradiction (0.55)
# A man in a business suit screaming at the camera .  ||  A business man is giving a warmed interview at the local news .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.027035343
# 1  :  0.09358954
# 2  :  0.09358954
# 3  :  0.12609679
# 4  :  0.17302237
# 5  :  0.17302237
# 6  :  0.17302237
# 7  :  0.17302237
# 8  :  0.2911583
# 9  :  0.30679432
# 10  :  0.36787793
# 11  :  0.36787793
# **** Attack failed ****
#
#
#
#
# 0  :  0.39790294
# ***** DONE  82 ------
# Original pred = neutral (0.74)
# A girl laying on the ground on her cellphone .  ||  a girl on her cellphone lying on the ground next to a dog
# ----------------------------------------
# New pred = entailment (0.69)
# A girl laying on the ground on her cellphone .  ||  a woman on her cellular lying on the ground next to a pooch
#
#
#
#
# 0  :  0.025104288
# 1  :  0.038772043
# 2  :  0.08536987
# 3  :  0.08680236
# 4  :  0.13226958
# 5  :  0.14735584
# 6  :  0.14735584
# 7  :  0.16480115
# 8  :  0.22267285
# 9  :  0.3044391
# 10  :  0.3044391
# 11  :  0.3044391
# **** Attack failed ****
#
#
#
#
# 0  :  0.35856876
# 1  :  0.4784904
# ***** DONE  84 ------
# Original pred = neutral (0.84)
# A group of young people performing on a stage .  ||  A group of people are singing and dancing on stage for people .
# ----------------------------------------
# New pred = Contradiction (0.54)
# A group of young people performing on a stage .  ||  A groups of people are chant and dancing on stage at people .
#
#
#
#
# 0  :  0.005491584
# 1  :  0.010588379
# 2  :  0.017077882
# 3  :  0.017077882
# 4  :  0.021025812
# 5  :  0.021025812
# 6  :  0.021025812
# 7  :  0.025220316
# 8  :  0.025220316
# 9  :  0.025220316
# 10  :  0.025220316
# 11  :  0.025220316
# **** Attack failed ****
#
#
#
#
#
#
# Wrong classified
#
#
# ***** DONE  86 ------
# Original pred = neutral (0.79)
# Two roadside workers with lime green safety jackets , white hard hats and gloves on with construction cones in the background  ||  Two men are placing construction cones in preparation of a new pipeline building .
# ----------------------------------------
# New pred = Contradiction (0.65)
# Two roadside workers with lime green safety jackets , white hard hats and gloves on with construction cones in the background  ||  Two men are placing construction pylons in preparation of a new pipeline building .
#
#
#
#
# 0  :  0.16367991
# 1  :  0.19818516
# 2  :  0.31211862
# 3  :  0.31211862
# 4  :  0.31211862
# 5  :  0.37988463
# 6  :  0.37988463
# ***** DONE  87 ------
# Original pred = entailment (0.76)
# Six rescuers cooperate to place an injured man on a transport device in snowy , mountainous terrain .  ||  six people act together to get another , injured man on a transport in snowy terrain
# ----------------------------------------
# New pred = Contradiction (0.51)
# Six rescuers cooperate to place an injured man on a transport device in snowy , mountainous terrain .  ||  six people act whole to get latest , wound man on a transport onto snowy terra
#
#
# ***** DONE  88 ------
# Original pred = neutral (0.57)
# A young dark-haired woman with red sun visor holding an open white umbrella amidst a crowd of people  ||  The attractive brunette in a red visor gets a lot of attention from the crowd as she holds a white umbrella .
# ----------------------------------------
# New pred = entailment (0.56)
# A young dark-haired woman with red sun visor holding an open white umbrella amidst a crowd of people  ||  The appealing brunette in a red visor gets a lot of attention from the crowd as she holds a white umbrella .
#
#
#
#
#
#
#
#
#
#
# 0  :  0.047353264
# 1  :  0.29788268
# 2  :  0.39883342
# 3  :  0.39883342
# ***** DONE  89 ------
# Original pred = neutral (0.90)
# Elderly woman in blue apron balances a basket on her head on a sidewalk while talking to a woman dressed in black .  ||  The woman balancing a basket on her head is heading to her neighbors house .
# ----------------------------------------
# New pred = entailment (0.47)
# Elderly woman in blue apron balances a basket on her head on a sidewalk while talking to a woman dressed in black .  ||  The female balanced a basket concerning her head is heading to her adjacent habitation .
#
#
#
#
# Wrong classified
#
#
#
#
# 0  :  0.17049034
# 1  :  0.17868836
# 2  :  0.17868836
# 3  :  0.26008686
# 4  :  0.26008686
# 5  :  0.26008686
# 6  :  0.28312445
# 7  :  0.30154616
# 8  :  0.32601357
# 9  :  0.32601357
# 10  :  0.32601357
# 11  :  0.32601357
# **** Attack failed ****
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***** DONE  91 ------
# Original pred = entailment (0.92)
# Four youth and an elder man and woman playing in water just up to the bottom of man 's swim trunks .  ||  A group of people are playing in the water .
# ----------------------------------------
# New pred = Contradiction (0.68)
# Four youth and an elder man and woman playing in water just up to the bottom of man 's swim trunks .  ||  A group of people are gaming in the water .
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.13903369
# ***** DONE  92 ------
# Original pred = entailment (0.96)
# A young woman skateboarding on an outdoor basketball court in front of a mural .  ||  A young woman skateboards on an outdoor basketball court .
# ----------------------------------------
# New pred = Contradiction (0.50)
# A young woman skateboarding on an outdoor basketball court in front of a mural .  ||  A young wife skateboards on an outboard basketball backyard .
#
#
#
#
# ***** DONE  93 ------
# Original pred = entailment (0.84)
# A sitting man is holding a partially carved stone in front a partially painted wall .  ||  A man is holding a stone in front of a wall .
# ----------------------------------------
# New pred = Contradiction (0.67)
# A sitting man is holding a partially carved stone in front a partially painted wall .  ||  A man is holding a pebble in front of a wall .
#
#
#
#
# 0  :  0.00023778273
# 1  :  0.0013271001
# 2  :  0.001637704
# 3  :  0.0022439975
# 4  :  0.0022439975
# 5  :  0.0040202714
# 6  :  0.0040202714
# 7  :  0.0040202714
# 8  :  0.004124028
# 9  :  0.004440569
# 10  :  0.004440569
# 11  :  0.0052304445
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.12361679
# 1  :  0.36746913
# ***** DONE  95 ------
# Original pred = neutral (0.95)
# Three guys in red uniforms celebrating a goal in a soccer game .  ||  Three men in red uniforms celebrating a goal in front of a crowd at a soccer stadium .
# ----------------------------------------
# New pred = Contradiction (0.76)
# Three guys in red uniforms celebrating a goal in a soccer game .  ||  Three men in red uniforms celebrating a goals in front of a crowd at a football colosseum .
#
#
#
#
# 0  :  0.11998848
# 1  :  0.19675928
# 2  :  0.19675928
# 3  :  0.21875136
# 4  :  0.27861583
# 5  :  0.27861583
# 6  :  0.29203677
# 7  :  0.33408323
# 8  :  0.33408323
# 9  :  0.33408323
# 10  :  0.33408323
# 11  :  0.33408323
# **** Attack failed ****
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.4104025
# ***** DONE  97 ------
# Original pred = neutral (0.83)
# The girl wearing a brown jacket whilst walking in snow .  ||  The lady wearing a jacket is looking for her lost dog .
# ----------------------------------------
# New pred = Contradiction (0.69)
# The girl wearing a brown jacket whilst walking in snow .  ||  The lady wearing a jacket is looking at her forfeited dog .
#
#
#
#
# 0  :  0.054883353
# 1  :  0.2686028
# 2  :  0.2686028
# 3  :  0.2686028
# 4  :  0.2686028
# ***** DONE  98 ------
# Original pred = neutral (0.98)
# A white dog holds a tennis ball in its mouth in a field .  ||  The dog is fetching the ball for its owner .
# ----------------------------------------
# New pred = entailment (0.56)
# A white dog holds a tennis ball in its mouth in a field .  ||  The pooch exists fetching the ball during its holders .
#
#
#
#
# 0  :  0.13387306
# 1  :  0.19353698
# 2  :  0.29261726
# 3  :  0.29261726
# 4  :  0.29261726
# ***** DONE  99 ------
# Original pred = neutral (0.84)
# A well dressed elderly woman standing in front of a bus decorated with images of purple flowers .  ||  A grandmother is standing in front of a bus with violets decorated all over it .
# ----------------------------------------
# New pred = Contradiction (0.50)
# A well dressed elderly woman standing in front of a bus decorated with images of purple flowers .  ||  A granma exists permanent throughout brow du a coach with violets decorated all over it .
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Wrong classified
#
#
#
#
# Wrong classified
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.33813992
# 1  :  0.39477864
# 2  :  0.39477864
# 3  :  0.43616518
# 4  :  0.43616518
# 5  :  0.43616518
# 6  :  0.43616518
# 7  :  0.43616518
# 8  :  0.43616518
# 9  :  0.43616518
# 10  :  0.43616518
# 11  :  0.43616518
# **** Attack failed ****
#
#
# ***** DONE  101 ------
# Original pred = Contradiction (0.95)
# A brown and white dog holds a tennis ball in his mouth .  ||  A dog is eating from a bright silver bowl .
# ----------------------------------------
# New pred = entailment (0.55)
# A brown and white dog holds a tennis ball in his mouth .  ||  A dog is nourishment from a bright silver bowl .
#
#
#
#
# 0  :  0.3098203
# 1  :  0.410933
# 2  :  0.410933
# ***** DONE  102 ------
# Original pred = neutral (0.78)
# Under the glaring light of a fluorescent bulb , men in dark clothing and hats approach fare card machines ; one older man in a blue scarf glances up as he puts on his gloves .  ||  The man are putting on their attire before going into the cold weather .
# ----------------------------------------
# New pred = entailment (0.48)
# Under the glaring light of a fluorescent bulb , men in dark clothing and hats approach fare card machines ; one older man in a blue scarf glances up as he puts on his gloves .  ||  The man are putting on their attire formerly going toward the chilled temperatures .
#
#
#
#
# 0  :  2.449535e-06
# 1  :  6.238e-06
# 2  :  1.06833895e-05
# 3  :  4.2413023e-05
# 4  :  4.2413023e-05
# 5  :  4.2413023e-05
# 6  :  5.4247328e-05
# 7  :  5.4247328e-05
# 8  :  5.4247328e-05
# 9  :  5.4247328e-05
# 10  :  5.4247328e-05
# 11  :  5.4247328e-05
# **** Attack failed ****
#
#
# ***** DONE  104 ------
# Original pred = neutral (0.57)
# A big dog catches a ball on his nose  ||  A big dog is sitting down while trying to catch a ball
# ----------------------------------------
# New pred = Contradiction (0.79)
# A big dog catches a ball on his nose  ||  A big dog is sitting down while trying to catch a football
#
#
#
#
#
#
#
#
#
#
#
#
# 0  :  0.09234692
# 1  :  0.15184748
# 2  :  0.19551064
# 3  :  0.21030824
# 4  :  0.21030824
# 5  :  0.21030824
# 6  :  0.23429827
# 7  :  0.30697268
# 8  :  0.31042054
# 9  :  0.31042054
# 10  :  0.31042054
# 11  :  0.31042054
# **** Attack failed ****
#
#
#
#
#
#
#
#
# 0  :  0.1193162
# 1  :  0.15066662
# 2  :  0.15066662
# 3  :  0.15066662
# 4  :  0.26064166
# 5  :  0.26064166
# 6  :  0.26064166
# 7  :  0.26064166
# 8  :  0.2694211
# 9  :  0.3279172
# 10  :  0.3279172
# 11  :  0.3279172
# **** Attack failed ****
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ***** DONE  107 ------
# Original pred = entailment (0.79)
# a snowboarder wearing a green hat is riding along a metal railing .  ||  A snowboarder is riding along a metal railing while wearing a green hat .
# ----------------------------------------
# New pred = Contradiction (0.55)
# a snowboarder wearing a green hat is riding along a metal railing .  ||  A skier is riding along a metal railing while wearing a green hat .
#
#
# 0  :  0.14045653
# 1  :  0.298401
# 2  :  0.298401
# 3  :  0.32850206
# 4  :  0.3548379
# ***** DONE  108 ------
# Original pred = entailment (0.84)
# A woman in an office making a phone call  ||  A woman is making a phone call in an office environment .
# ----------------------------------------
# New pred = Contradiction (0.47)
# A woman in an office making a phone call  ||  A girl is doing a phones invitation in an office surroundings .
# 0.6788990825688074

# %%
print('Success rate: ', (success_count / len(test_list)))
# Out:
# Success rate:  0.6788990825688074
